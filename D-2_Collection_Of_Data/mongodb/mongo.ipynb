# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client["Mho-DB_1"]
col = db["employees"]

for doc in col.find():
    print(doc)
# Out:
# {'_id': ObjectId('686e85c551bf8abeb6b8bfe6'), 'id': 1, 'firstName': 'John', 'lastName': 'Doe', 'gender': 'Male', 'email': 'john.doe@example.com', 'salary': 60000, 'department': {'name': 'Engineering'}, 'skills': ['MongoDb', 'AWS', 'Express', 'C#']}
# {'_id': ObjectId('686e85c551bf8abeb6b8bfe7'), 'id': 2, 'firstName': 'Jane', 'lastName': 'Smith', 'gender': 'Female', 'email': 'jane.smith@example.com', 'salary': 65000, 'department': {'name': 'Marketing'}, 'skills': ['MongoDb', 'AWS', 'Express', 'C#']}
# {'_id': ObjectId('686e85c551bf8abeb6b8bfe8'), 'id': 3, 'firstName': 'Michael', 'lastName': 'Brown', 'gender': 'Male', 'email': 'michael.brown@example.com', 'salary': 58000, 'department': {'name': 'Engineering'}, 'skills': ['MongoDb', 'AWS', 'Express', 'C#']}
# ...
